# %% [markdown]
# ### Importing necessary libraries..

# %%
import numpy as np
import cv2
import os
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd
from imutils.face_utils import FaceAligner
from imutils.face_utils import rect_to_bb
import imutils
import dlib

# %% [markdown]
# ### Loading the images and labels and Preprocessing the Dataset

# %%
data = np.load('data.npz', allow_pickle=True)
X = data['arr_0']  # Closed
Y = data['arr_1']  # Open
X = list(X)
Y = list(Y)
print(len(X))
print(len(Y))
# Out:
# 1452
# 1452

# %%
# Resize images to the required input size (32x32)
for i in range(len(X)):
    img = X[i]
    img = cv2.resize(img, (32, 32))
    X[i] = img
    
print(len(X))
print(X[0].shape)
# Out:
# 1452
# (32, 32, 3)

# %%
# Encode the labels into numerical format (0 for 'Closed', 1 for 'Open')
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)
print(Y.shape)
print(Y[0])
print(set(Y))
# Out:
# (1452,)
# 0
# {0, 1}

# %%
# Convert images and labels into numpy arrays for easier handling
X = np.array(X)
Y = np.array(Y)
print(X.shape)
print(Y.shape)
# Out:
# (1452, 32, 32, 3)
# (1452,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2) # Split the data into training and testing sets

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1161, 32, 32, 3)
# (1161, 2)
# (291, 32, 32, 3)
# (291, 2)

# %%
# One-hot encode the labels for training and testing sets
Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1161, 32, 32, 3)
# (1161, 2, 2)
# (291, 32, 32, 3)
# (291, 2, 2)

# %% [markdown]
# ### Visualizing images of Closed Eye and Open Eye from the Dataset

# %%
# Display an image of a "Closed Eye" to visualize the data
figure1 = plt.figure(figsize=(5, 5))
idx_closed = np.where(Y==0)
img_closed = X[idx_closed[0][0]]
plt.imshow(img_closed)
plt.title('Image of Closed Eye representing Driver is sleeping')
plt.axis('off')
plt.show()
# Display an image of an "Open Eye" to visualize the data
figure2 = plt.figure(figsize=(5, 5))
idx_open = np.where(Y==1)
img_open = X[idx_open[0][0]]
plt.imshow(img_open)
plt.title('Image of Open Eye representing Driver is not sleeping')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Visualizing the Data Distribution in Train and Test Set

# %%
unique_train, count = np.unique(Y_train, return_counts=True)

plt.figure(figsize=(20, 10))
sns.barplot(x=unique_train, y=count).set_title("Number of training images per category:")
plt.xlabel('Categories')  
plt.ylabel('Number of Images') 
plt.show()

# %%
unique_test, count_test = np.unique(Y_test, return_counts=True)

plt.figure(figsize=(20, 10))
sns.barplot(x=unique_test, y=count_test).set_title("Number of test images per category:")
plt.xlabel('Categories')  
plt.ylabel('Number of Images')  
plt.show()

# %% [markdown]
# ### Defining the Model Architecture

# %%
# Define the CNN architecture for the driver drowsiness detection model
def driver_drowsiness_detection_model(input_shape=(32, 32, 3)):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv1', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv2', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv5', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv6', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv7', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    
    model.add(Flatten()) # Flatten the output for the fully connected layer
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer=glorot_uniform(seed=0), name='fc3'))  # Output layer
    
    optimizer = Adam(0.0001) # Adam optimizer with learning rate of 0.0001
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# Initialize and summarize the model architecture
model= driver_drowsiness_detection_model(input_shape=(32, 32, 3))
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1 (Conv2D)                  │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4 (Conv2D)                  │ (None, 8, 8, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv5 (Conv2D)                  │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 4, 4, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv6 (Conv2D)                  │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 4, 4, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv7 (Conv2D)                  │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 4, 4, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc3 (Dense)                     │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 227,554 (888.88 KB)
#  Trainable params: 226,786 (885.88 KB)
#  Non-trainable params: 768 (3.00 KB)

# %%
# Define data augmentation techniques to enhance the training data
aug = ImageDataGenerator(rotation_range=20, zoom_range=0.2, horizontal_flip=True)
# Train the model with the augmented data and validation set
hist = model.fit(aug.flow(X_train, Y_train, batch_size=128), batch_size=128, epochs=200, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/200
# c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 180ms/step - accuracy: 0.4764 - loss: 1.3776 - val_accuracy: 0.5086 - val_loss: 0.6788
# Epoch 2/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.5357 - loss: 1.2946 - val_accuracy: 0.5430 - val_loss: 0.6665
# Epoch 3/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - accuracy: 0.5340 - loss: 1.1345 - val_accuracy: 0.6014 - val_loss: 0.6543
# Epoch 4/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 0.5686 - loss: 1.0750 - val_accuracy: 0.6254 - val_loss: 0.6366
# Epoch 5/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - accuracy: 0.6425 - loss: 0.8407 - val_accuracy: 0.7010 - val_loss: 0.6167
# Epoch 6/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.5637 - loss: 0.9009 - val_accuracy: 0.7801 - val_loss: 0.6027
# Epoch 7/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 219ms/step - accuracy: 0.5909 - loss: 0.9056 - val_accuracy: 0.7835 - val_loss: 0.5960
# Epoch 8/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.6265 - loss: 0.8223 - val_accuracy: 0.7904 - val_loss: 0.5902
# Epoch 9/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.6314 - loss: 0.7251 - val_accuracy: 0.7698 - val_loss: 0.5865
# Epoch 10/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.6124 - loss: 0.7819 - val_accuracy: 0.7491 - val_loss: 0.5817
# Epoch 11/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.6650 - loss: 0.6754 - val_accuracy: 0.7457 - val_loss: 0.5748
# Epoch 12/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.6456 - loss: 0.8125 - val_accuracy: 0.7388 - val_loss: 0.5662
# Epoch 13/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.6590 - loss: 0.6322 - val_accuracy: 0.7423 - val_loss: 0.5576
# Epoch 14/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.6535 - loss: 0.7888 - val_accuracy: 0.7423 - val_loss: 0.5490
# Epoch 15/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6803 - loss: 0.6427 - val_accuracy: 0.7526 - val_loss: 0.5377
# Epoch 16/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.7027 - loss: 0.6331 - val_accuracy: 0.7560 - val_loss: 0.5273
# Epoch 17/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.6681 - loss: 0.6391 - val_accuracy: 0.7732 - val_loss: 0.5136
# Epoch 18/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.7039 - loss: 0.5813 - val_accuracy: 0.7869 - val_loss: 0.4995
# Epoch 19/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - accuracy: 0.7244 - loss: 0.6258 - val_accuracy: 0.7835 - val_loss: 0.4873
# Epoch 20/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.7066 - loss: 0.5898 - val_accuracy: 0.8041 - val_loss: 0.4729
# Epoch 21/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - accuracy: 0.7152 - loss: 0.5851 - val_accuracy: 0.8144 - val_loss: 0.4577
# Epoch 22/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.7073 - loss: 0.6285 - val_accuracy: 0.8076 - val_loss: 0.4469
# Epoch 23/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - accuracy: 0.7324 - loss: 0.5265 - val_accuracy: 0.8144 - val_loss: 0.4344
# Epoch 24/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.7576 - loss: 0.5402 - val_accuracy: 0.8282 - val_loss: 0.4208
# Epoch 25/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - accuracy: 0.7691 - loss: 0.5213 - val_accuracy: 0.8351 - val_loss: 0.4066
# Epoch 26/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.7654 - loss: 0.4800 - val_accuracy: 0.8419 - val_loss: 0.3940
# Epoch 27/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.7252 - loss: 0.5322 - val_accuracy: 0.8454 - val_loss: 0.3800
# Epoch 28/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - accuracy: 0.7501 - loss: 0.6031 - val_accuracy: 0.8522 - val_loss: 0.3680
# Epoch 29/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - accuracy: 0.7726 - loss: 0.5244 - val_accuracy: 0.8660 - val_loss: 0.3553
# Epoch 30/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.7839 - loss: 0.4775 - val_accuracy: 0.8625 - val_loss: 0.3447
# Epoch 31/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.7803 - loss: 0.4626 - val_accuracy: 0.8625 - val_loss: 0.3336
# Epoch 32/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.7753 - loss: 0.4855 - val_accuracy: 0.8591 - val_loss: 0.3228
# Epoch 33/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.8016 - loss: 0.5026 - val_accuracy: 0.8660 - val_loss: 0.3149
# Epoch 34/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - accuracy: 0.8181 - loss: 0.4513 - val_accuracy: 0.8660 - val_loss: 0.3065
# Epoch 35/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 0.8145 - loss: 0.4161 - val_accuracy: 0.8694 - val_loss: 0.3012
# Epoch 36/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - accuracy: 0.8343 - loss: 0.4259 - val_accuracy: 0.8660 - val_loss: 0.2933
# Epoch 37/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.8236 - loss: 0.3982 - val_accuracy: 0.8660 - val_loss: 0.2851
# Epoch 38/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.8607 - loss: 0.3803 - val_accuracy: 0.8694 - val_loss: 0.2747
# Epoch 39/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.8429 - loss: 0.3891 - val_accuracy: 0.8729 - val_loss: 0.2645
# Epoch 40/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.8548 - loss: 0.3467 - val_accuracy: 0.8729 - val_loss: 0.2582
# Epoch 41/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 0.8526 - loss: 0.3691 - val_accuracy: 0.8832 - val_loss: 0.2521
# Epoch 42/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.8778 - loss: 0.3314 - val_accuracy: 0.8866 - val_loss: 0.2478
# Epoch 43/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.8567 - loss: 0.3431 - val_accuracy: 0.8832 - val_loss: 0.2425
# Epoch 44/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.8533 - loss: 0.3741 - val_accuracy: 0.8866 - val_loss: 0.2365
# Epoch 45/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.8818 - loss: 0.2987 - val_accuracy: 0.8935 - val_loss: 0.2302
# Epoch 46/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.8814 - loss: 0.3197 - val_accuracy: 0.8935 - val_loss: 0.2246
# Epoch 47/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8825 - loss: 0.3059 - val_accuracy: 0.8969 - val_loss: 0.2200
# Epoch 48/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.8913 - loss: 0.2831 - val_accuracy: 0.9003 - val_loss: 0.2164
# Epoch 49/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - accuracy: 0.8922 - loss: 0.2855 - val_accuracy: 0.9072 - val_loss: 0.2094
# Epoch 50/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 196ms/step - accuracy: 0.8853 - loss: 0.2654 - val_accuracy: 0.9175 - val_loss: 0.2038
# Epoch 51/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - accuracy: 0.8925 - loss: 0.2849 - val_accuracy: 0.9244 - val_loss: 0.1995
# Epoch 52/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - accuracy: 0.9068 - loss: 0.2538 - val_accuracy: 0.9244 - val_loss: 0.1953
# Epoch 53/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.9069 - loss: 0.2422 - val_accuracy: 0.9244 - val_loss: 0.1930
# Epoch 54/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.9157 - loss: 0.2414 - val_accuracy: 0.9244 - val_loss: 0.1892
# Epoch 55/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - accuracy: 0.9002 - loss: 0.2334 - val_accuracy: 0.9313 - val_loss: 0.1870
# Epoch 56/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.9203 - loss: 0.2050 - val_accuracy: 0.9244 - val_loss: 0.1893
# Epoch 57/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - accuracy: 0.9158 - loss: 0.2120 - val_accuracy: 0.9244 - val_loss: 0.1897
# Epoch 58/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.9042 - loss: 0.2318 - val_accuracy: 0.9313 - val_loss: 0.1894
# Epoch 59/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.9199 - loss: 0.2029 - val_accuracy: 0.9347 - val_loss: 0.1853
# Epoch 60/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 175ms/step - accuracy: 0.9207 - loss: 0.2105 - val_accuracy: 0.9313 - val_loss: 0.1817
# Epoch 61/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 175ms/step - accuracy: 0.9348 - loss: 0.1733 - val_accuracy: 0.9313 - val_loss: 0.1801
# Epoch 62/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - accuracy: 0.9215 - loss: 0.2370 - val_accuracy: 0.9313 - val_loss: 0.1807
# Epoch 63/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - accuracy: 0.9310 - loss: 0.1921 - val_accuracy: 0.9278 - val_loss: 0.1795
# Epoch 64/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - accuracy: 0.9280 - loss: 0.2125 - val_accuracy: 0.9347 - val_loss: 0.1803
# Epoch 65/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 0.9108 - loss: 0.2403 - val_accuracy: 0.9416 - val_loss: 0.1871
# Epoch 66/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - accuracy: 0.9386 - loss: 0.2039 - val_accuracy: 0.9416 - val_loss: 0.1849
# Epoch 67/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9204 - loss: 0.2028 - val_accuracy: 0.9416 - val_loss: 0.1781
# Epoch 68/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 223ms/step - accuracy: 0.9259 - loss: 0.1804 - val_accuracy: 0.9313 - val_loss: 0.1730
# Epoch 69/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - accuracy: 0.9178 - loss: 0.1877 - val_accuracy: 0.9347 - val_loss: 0.1739
# Epoch 70/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - accuracy: 0.9293 - loss: 0.2068 - val_accuracy: 0.9416 - val_loss: 0.1790
# Epoch 71/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.9371 - loss: 0.1712 - val_accuracy: 0.9381 - val_loss: 0.1815
# Epoch 72/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.9230 - loss: 0.1960 - val_accuracy: 0.9347 - val_loss: 0.1809
# Epoch 73/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - accuracy: 0.9487 - loss: 0.1625 - val_accuracy: 0.9313 - val_loss: 0.1836
# Epoch 74/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.9567 - loss: 0.1543 - val_accuracy: 0.9381 - val_loss: 0.1759
# Epoch 75/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - accuracy: 0.9350 - loss: 0.1696 - val_accuracy: 0.9450 - val_loss: 0.1608
# Epoch 76/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.9563 - loss: 0.1329 - val_accuracy: 0.9450 - val_loss: 0.1623
# Epoch 77/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.9492 - loss: 0.1643 - val_accuracy: 0.9519 - val_loss: 0.1691
# Epoch 78/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.9492 - loss: 0.1526 - val_accuracy: 0.9450 - val_loss: 0.1659
# Epoch 79/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - accuracy: 0.9580 - loss: 0.1174 - val_accuracy: 0.9485 - val_loss: 0.1659
# Epoch 80/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - accuracy: 0.9494 - loss: 0.1504 - val_accuracy: 0.9347 - val_loss: 0.1638
# Epoch 81/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.9526 - loss: 0.1317 - val_accuracy: 0.9450 - val_loss: 0.1591
# Epoch 82/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - accuracy: 0.9526 - loss: 0.1417 - val_accuracy: 0.9553 - val_loss: 0.1494
# Epoch 83/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - accuracy: 0.9417 - loss: 0.1905 - val_accuracy: 0.9450 - val_loss: 0.1596
# Epoch 84/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.9538 - loss: 0.1444 - val_accuracy: 0.9416 - val_loss: 0.1625
# Epoch 85/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.9549 - loss: 0.1283 - val_accuracy: 0.9416 - val_loss: 0.1614
# Epoch 86/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.9448 - loss: 0.1506 - val_accuracy: 0.9588 - val_loss: 0.1580
# Epoch 87/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.9519 - loss: 0.1223 - val_accuracy: 0.9553 - val_loss: 0.1489
# Epoch 88/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - accuracy: 0.9365 - loss: 0.1504 - val_accuracy: 0.9347 - val_loss: 0.1637
# Epoch 89/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - accuracy: 0.9382 - loss: 0.1468 - val_accuracy: 0.9519 - val_loss: 0.1459
# Epoch 90/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.9318 - loss: 0.3089 - val_accuracy: 0.9588 - val_loss: 0.1367
# Epoch 91/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 0.9600 - loss: 0.1163 - val_accuracy: 0.9519 - val_loss: 0.1332
# Epoch 92/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.9467 - loss: 0.1530 - val_accuracy: 0.9450 - val_loss: 0.1376
# Epoch 93/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.9612 - loss: 0.1274 - val_accuracy: 0.9450 - val_loss: 0.1470
# Epoch 94/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.9608 - loss: 0.1245 - val_accuracy: 0.9519 - val_loss: 0.1460
# Epoch 95/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.9504 - loss: 0.1255 - val_accuracy: 0.9416 - val_loss: 0.1474
# Epoch 96/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9547 - loss: 0.1200 - val_accuracy: 0.9485 - val_loss: 0.1451
# Epoch 97/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.9542 - loss: 0.1188 - val_accuracy: 0.9485 - val_loss: 0.1606
# Epoch 98/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.9677 - loss: 0.0985 - val_accuracy: 0.9485 - val_loss: 0.1528
# Epoch 99/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - accuracy: 0.9611 - loss: 0.1264 - val_accuracy: 0.9485 - val_loss: 0.1449
# Epoch 100/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.9590 - loss: 0.1306 - val_accuracy: 0.9485 - val_loss: 0.1321
# Epoch 101/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9578 - loss: 0.1133 - val_accuracy: 0.9622 - val_loss: 0.1249
# Epoch 102/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9583 - loss: 0.1202 - val_accuracy: 0.9588 - val_loss: 0.1279
# Epoch 103/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9563 - loss: 0.1848 - val_accuracy: 0.9588 - val_loss: 0.1265
# Epoch 104/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9716 - loss: 0.0916 - val_accuracy: 0.9450 - val_loss: 0.1292
# Epoch 105/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 0.9618 - loss: 0.1097 - val_accuracy: 0.9588 - val_loss: 0.1247
# Epoch 106/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.9682 - loss: 0.1055 - val_accuracy: 0.9588 - val_loss: 0.1340
# Epoch 107/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - accuracy: 0.9648 - loss: 0.0822 - val_accuracy: 0.9553 - val_loss: 0.1311
# Epoch 108/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9656 - loss: 0.1021 - val_accuracy: 0.9553 - val_loss: 0.1245
# Epoch 109/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.9691 - loss: 0.1086 - val_accuracy: 0.9588 - val_loss: 0.1206
# Epoch 110/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 0.9625 - loss: 0.0951 - val_accuracy: 0.9622 - val_loss: 0.1250
# Epoch 111/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - accuracy: 0.9626 - loss: 0.1071 - val_accuracy: 0.9588 - val_loss: 0.1177
# Epoch 112/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - accuracy: 0.9598 - loss: 0.1141 - val_accuracy: 0.9622 - val_loss: 0.1086
# Epoch 113/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - accuracy: 0.9625 - loss: 0.0968 - val_accuracy: 0.9622 - val_loss: 0.1102
# Epoch 114/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.9659 - loss: 0.0930 - val_accuracy: 0.9656 - val_loss: 0.1094
# Epoch 115/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.9532 - loss: 0.1218 - val_accuracy: 0.9656 - val_loss: 0.1102
# Epoch 116/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.9678 - loss: 0.0799 - val_accuracy: 0.9588 - val_loss: 0.1098
# Epoch 117/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 0.9629 - loss: 0.0892 - val_accuracy: 0.9519 - val_loss: 0.1173
# Epoch 118/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.9576 - loss: 0.1043 - val_accuracy: 0.9450 - val_loss: 0.1247
# Epoch 119/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.9646 - loss: 0.0860 - val_accuracy: 0.9622 - val_loss: 0.1131
# Epoch 120/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9746 - loss: 0.0886 - val_accuracy: 0.9553 - val_loss: 0.1188
# Epoch 121/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.9645 - loss: 0.0929 - val_accuracy: 0.9622 - val_loss: 0.1153
# Epoch 122/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9740 - loss: 0.0881 - val_accuracy: 0.9622 - val_loss: 0.1148
# Epoch 123/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.9776 - loss: 0.0796 - val_accuracy: 0.9588 - val_loss: 0.1125
# Epoch 124/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 0.9718 - loss: 0.0894 - val_accuracy: 0.9588 - val_loss: 0.1120
# Epoch 125/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9764 - loss: 0.0754 - val_accuracy: 0.9622 - val_loss: 0.1077
# Epoch 126/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 0.9696 - loss: 0.0709 - val_accuracy: 0.9622 - val_loss: 0.1085
# Epoch 127/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - accuracy: 0.9773 - loss: 0.0692 - val_accuracy: 0.9622 - val_loss: 0.1147
# Epoch 128/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9616 - loss: 0.0982 - val_accuracy: 0.9553 - val_loss: 0.1179
# Epoch 129/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9666 - loss: 0.0931 - val_accuracy: 0.9622 - val_loss: 0.1086
# Epoch 130/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9692 - loss: 0.0936 - val_accuracy: 0.9656 - val_loss: 0.0969
# Epoch 131/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9770 - loss: 0.0757 - val_accuracy: 0.9519 - val_loss: 0.1533
# Epoch 132/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - accuracy: 0.9558 - loss: 0.1450 - val_accuracy: 0.9485 - val_loss: 0.1477
# Epoch 133/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9514 - loss: 0.1214 - val_accuracy: 0.9553 - val_loss: 0.1308
# Epoch 134/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9727 - loss: 0.0857 - val_accuracy: 0.9485 - val_loss: 0.1153
# Epoch 135/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9720 - loss: 0.0801 - val_accuracy: 0.9553 - val_loss: 0.1131
# Epoch 136/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.9709 - loss: 0.0700 - val_accuracy: 0.9588 - val_loss: 0.1079
# Epoch 137/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.9675 - loss: 0.0902 - val_accuracy: 0.9588 - val_loss: 0.1081
# Epoch 138/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9717 - loss: 0.0723 - val_accuracy: 0.9588 - val_loss: 0.1041
# Epoch 139/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.9818 - loss: 0.0505 - val_accuracy: 0.9553 - val_loss: 0.1027
# Epoch 140/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.9840 - loss: 0.0742 - val_accuracy: 0.9553 - val_loss: 0.1129
# Epoch 141/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.9683 - loss: 0.1014 - val_accuracy: 0.9553 - val_loss: 0.1117
# Epoch 142/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9847 - loss: 0.0515 - val_accuracy: 0.9622 - val_loss: 0.1041
# Epoch 143/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 0.9763 - loss: 0.0545 - val_accuracy: 0.9725 - val_loss: 0.0901
# Epoch 144/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9742 - loss: 0.0726 - val_accuracy: 0.9725 - val_loss: 0.0820
# Epoch 145/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.9856 - loss: 0.0535 - val_accuracy: 0.9725 - val_loss: 0.0837
# Epoch 146/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9675 - loss: 0.0946 - val_accuracy: 0.9725 - val_loss: 0.0833
# Epoch 147/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9722 - loss: 0.0599 - val_accuracy: 0.9656 - val_loss: 0.0996
# Epoch 148/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.9746 - loss: 0.0696 - val_accuracy: 0.9691 - val_loss: 0.0884
# Epoch 149/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9758 - loss: 0.0767 - val_accuracy: 0.9622 - val_loss: 0.0892
# Epoch 150/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.9754 - loss: 0.0603 - val_accuracy: 0.9656 - val_loss: 0.0941
# Epoch 151/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9758 - loss: 0.0657 - val_accuracy: 0.9691 - val_loss: 0.0910
# Epoch 152/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9726 - loss: 0.0683 - val_accuracy: 0.9725 - val_loss: 0.0849
# Epoch 153/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.9819 - loss: 0.0547 - val_accuracy: 0.9656 - val_loss: 0.0844
# Epoch 154/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.9765 - loss: 0.0588 - val_accuracy: 0.9759 - val_loss: 0.0794
# Epoch 155/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9760 - loss: 0.0604 - val_accuracy: 0.9725 - val_loss: 0.0823
# Epoch 156/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.9659 - loss: 0.1029 - val_accuracy: 0.9656 - val_loss: 0.0761
# Epoch 157/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9814 - loss: 0.0501 - val_accuracy: 0.9691 - val_loss: 0.0785
# Epoch 158/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9724 - loss: 0.0593 - val_accuracy: 0.9691 - val_loss: 0.0802
# Epoch 159/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.9838 - loss: 0.0401 - val_accuracy: 0.9725 - val_loss: 0.0774
# Epoch 160/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9805 - loss: 0.0515 - val_accuracy: 0.9691 - val_loss: 0.0797
# Epoch 161/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9810 - loss: 0.0541 - val_accuracy: 0.9691 - val_loss: 0.0874
# Epoch 162/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9831 - loss: 0.0417 - val_accuracy: 0.9656 - val_loss: 0.0905
# Epoch 163/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.9732 - loss: 0.0687 - val_accuracy: 0.9656 - val_loss: 0.0881
# Epoch 164/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.9805 - loss: 0.0483 - val_accuracy: 0.9691 - val_loss: 0.0893
# Epoch 165/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.9810 - loss: 0.0568 - val_accuracy: 0.9725 - val_loss: 0.0976
# Epoch 166/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9860 - loss: 0.0375 - val_accuracy: 0.9725 - val_loss: 0.0896
# Epoch 167/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.9812 - loss: 0.0564 - val_accuracy: 0.9725 - val_loss: 0.0901
# Epoch 168/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.9792 - loss: 0.0575 - val_accuracy: 0.9588 - val_loss: 0.1245
# Epoch 169/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9756 - loss: 0.0671 - val_accuracy: 0.9656 - val_loss: 0.1107
# Epoch 170/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9759 - loss: 0.0755 - val_accuracy: 0.9691 - val_loss: 0.0804
# Epoch 171/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9767 - loss: 0.0581 - val_accuracy: 0.9656 - val_loss: 0.0825
# Epoch 172/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9742 - loss: 0.0601 - val_accuracy: 0.9691 - val_loss: 0.0833
# Epoch 173/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.9780 - loss: 0.0531 - val_accuracy: 0.9691 - val_loss: 0.0796
# Epoch 174/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.9840 - loss: 0.0377 - val_accuracy: 0.9691 - val_loss: 0.0784
# Epoch 175/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9837 - loss: 0.0750 - val_accuracy: 0.9656 - val_loss: 0.0798
# Epoch 176/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.9904 - loss: 0.0350 - val_accuracy: 0.9725 - val_loss: 0.0822
# Epoch 177/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9848 - loss: 0.0525 - val_accuracy: 0.9691 - val_loss: 0.0720
# Epoch 178/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - accuracy: 0.9809 - loss: 0.0537 - val_accuracy: 0.9691 - val_loss: 0.0682
# Epoch 179/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - accuracy: 0.9778 - loss: 0.0571 - val_accuracy: 0.9656 - val_loss: 0.0700
# Epoch 180/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9893 - loss: 0.0412 - val_accuracy: 0.9691 - val_loss: 0.0740
# Epoch 181/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9870 - loss: 0.0378 - val_accuracy: 0.9691 - val_loss: 0.0774
# Epoch 182/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.9832 - loss: 0.0402 - val_accuracy: 0.9622 - val_loss: 0.0905
# Epoch 183/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 196ms/step - accuracy: 0.9754 - loss: 0.0619 - val_accuracy: 0.9656 - val_loss: 0.0811
# Epoch 184/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.9824 - loss: 0.0642 - val_accuracy: 0.9691 - val_loss: 0.0656
# Epoch 185/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step - accuracy: 0.9888 - loss: 0.0332 - val_accuracy: 0.9759 - val_loss: 0.0594
# Epoch 186/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9824 - loss: 0.0450 - val_accuracy: 0.9725 - val_loss: 0.0626
# Epoch 187/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - accuracy: 0.9830 - loss: 0.0551 - val_accuracy: 0.9794 - val_loss: 0.0669
# Epoch 188/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9876 - loss: 0.0409 - val_accuracy: 0.9759 - val_loss: 0.0675
# Epoch 189/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.9812 - loss: 0.0497 - val_accuracy: 0.9759 - val_loss: 0.0682
# Epoch 190/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.9712 - loss: 0.0705 - val_accuracy: 0.9725 - val_loss: 0.0762
# Epoch 191/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.9852 - loss: 0.0407 - val_accuracy: 0.9656 - val_loss: 0.0788
# Epoch 192/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.9803 - loss: 0.0546 - val_accuracy: 0.9691 - val_loss: 0.0792
# Epoch 193/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.9893 - loss: 0.0368 - val_accuracy: 0.9691 - val_loss: 0.0801
# Epoch 194/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - accuracy: 0.9820 - loss: 0.0455 - val_accuracy: 0.9656 - val_loss: 0.0757
# Epoch 195/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.9932 - loss: 0.0292 - val_accuracy: 0.9759 - val_loss: 0.0722
# Epoch 196/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9895 - loss: 0.0387 - val_accuracy: 0.9759 - val_loss: 0.0678
# Epoch 197/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9875 - loss: 0.0349 - val_accuracy: 0.9725 - val_loss: 0.0660
# Epoch 198/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.9857 - loss: 0.0315 - val_accuracy: 0.9759 - val_loss: 0.0656
# Epoch 199/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9804 - loss: 0.0517 - val_accuracy: 0.9794 - val_loss: 0.0764
# Epoch 200/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.9787 - loss: 0.0698 - val_accuracy: 0.9863 - val_loss: 0.0579

# %% [markdown]
# ### Plotting Loss Values and Accuracy against Number of Epochs for Train Set and Test Set

# %%
# Plot the model's accuracy during training and validation
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

# Plot the model's loss during training and validation
figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ### Evaluating Model on Test Set

# %%
# Evaluate the model's performance on the test set
pred = model.evaluate(X_test, Y_test)
print(f'Test Set Accuracy: {pred[1]}')
print(f'Test Set Loss: {pred[0]}')
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9829 - loss: 0.0666
# Test Set Accuracy: 0.9862542748451233
# Test Set Loss: 0.05786516144871712

# %% [markdown]
# ### Classification Report

# %%
# Generate and print classification report for test set
ypred = model.predict(X_test)
ypred = np.argmax(ypred, axis=1)
Y_test_pred = np.argmax(Y_test, axis=1)
print(classification_report(Y_test_pred, ypred))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       142
#            1       0.99      0.99      0.99       149
#
#     accuracy                           0.99       291
#    macro avg       0.99      0.99      0.99       291
# weighted avg       0.99      0.99      0.99       291

# %% [markdown]
# ### Confusion Matrix

# %%
# Generate and visualize confusion matrix
matrix = confusion_matrix(Y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')
# Out:
# <Axes: >

# %% [markdown]
# ### Saving the Model

# %%
# Save the trained model to a file for later use
model.save('Driver_Drowsiness_Detection_Model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Testing Model on Images

# %% [markdown]
# ### Testing the classification performnace on random images of Open and Closed Eyes

# %%
# Testing the model's performance on random images of open and closed eyes
labels = ['Closed', 'Open']
img_closed1 = cv2.imread('.jpg')
img_closed2 = cv2.imread('.jpg')
img_open1 = cv2.imread('.jpg')
img_open2 = cv2.imread('.jpg')

# Preprocess and predict on the test images
img_closed1 = cv2.resize(img_closed1, (32, 32))
img_closed2 = cv2.resize(img_closed2, (32, 32))
img_open1 = cv2.resize(img_open1, (32, 32))
img_open2 = cv2.resize(img_open2, (32, 32))

img_closed1 = np.array(img_closed1)
img_closed2 = np.array(img_closed2)
img_open1 = np.array(img_open1)
img_open2 = np.array(img_open2)

# Add extra dimension to images as they are single instances
img_closed1 = np.expand_dims(img_closed1, axis=0)
img_closed2 = np.expand_dims(img_closed2, axis=0)
img_open1 = np.expand_dims(img_open1, axis=0)
img_open2 = np.expand_dims(img_open2, axis=0)

# %%
# Predict labels for the test images
ypred_closed1 = model.predict(img_closed1)
ypred_closed2 = model.predict(img_closed2)
ypred_open1 = model.predict(img_open1)
ypred_open2 = model.predict(img_open2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
# Display the test images and the model's predictions
figure = plt.figure(figsize=(2, 2))
img_closed1 = np.squeeze(img_closed1, axis=0)
plt.imshow(img_closed1)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_closed1[0], axis=0)]}')
plt.show()

# %%
# Display the test images and the model's predictions
figure = plt.figure(figsize=(2, 2))
img_closed2 = np.squeeze(img_closed2, axis=0)
plt.imshow(img_closed2)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_closed2[0], axis=0)]}')
plt.show()

# %%
# Display the test images and the model's predictions
figure = plt.figure(figsize=(2, 2))
img_open1 = np.squeeze(img_open1, axis=0)
plt.imshow(img_open1)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_open1[0], axis=0)]}')
plt.show()

# %%
# Display the test images and the model's predictions
figure = plt.figure(figsize=(2, 2))
img_open2 = np.squeeze(img_open2, axis=0)
plt.imshow(img_open2)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_open2[0], axis=0)]}')
plt.show()
